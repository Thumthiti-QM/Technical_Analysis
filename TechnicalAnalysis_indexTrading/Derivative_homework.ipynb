# %%
date_open_list = []
date_close_list = []
Pnl_list = []
execution_list = []

# %%
import pandas as pd
import backtrader as bt
from datetime import datetime


class BOLLStrat(bt.Strategy):
    
    date_open_list = []
    date_close_list = []
    Pnl_list = []
    execution_list = []
    
    '''
    This is a simple mean reversion bollinger band strategy.

    Entry Critria:
        - Long:
            - Price closes below the lower band
        - Short:
            - Price closes above the upper band
    Exit Critria
        - Long/Short: Price touching the median line
    '''

    params = (
        ("period", 10),
        ("devfactor", 1),
        ("size", 1),
        ("debug", False)
        )

    def __init__(self):
        self.boll = bt.indicators.BollingerBands(period=self.p.period, devfactor=self.p.devfactor)

    def next(self):

        orders = self.broker.get_orders_open()

        # Cancel open orders so we can track the median line
        if orders:
            for order in orders:
                self.broker.cancel(order)

        if not self.position:

            if self.data.close > self.boll.lines.top:

                self.sell(exectype=bt.Order.Close, size=self.p.size)
                print(data.close)
            if self.data.close < self.boll.lines.bot:
                self.buy(exectype=bt.Order.Close, size=self.p.size)
                print(data.close)

        else:


            if self.position.size > 0:
                self.sell(exectype=bt.Order.Limit, price=self.boll.lines.mid[0], size=self.p.size)

            else:
                self.buy(exectype=bt.Order.Limit, price=self.boll.lines.mid[0], size=self.p.size)

        if self.p.debug:
            print('---------------------------- NEXT ----------------------------------')
            print("1: Data Name:                            {}".format(data._name))
            print("2: Bar Num:                              {}".format(len(data)))
            print("3: Current date:                         {}".format(data.datetime.datetime()))
            print('4: Open:                                 {}'.format(data.open[0]))
            print('5: High:                                 {}'.format(data.high[0]))
            print('6: Low:                                  {}'.format(data.low[0]))
            print('7: Close:                                {}'.format(data.close[0]))
            print('8: Volume:                               {}'.format(data.volume[0]))
            print('9: Position Size:                       {}'.format(self.position.size))
            print('--------------------------------------------------------------------')

    def notify_trade(self,trade):
        if trade.isopen:
            print("size_{}".format(trade.size))
            print("trade_open_{}".format(trade.price))
            execution_list.append(trade.size)
            

    
        
        if trade.isclosed:
            print("size_{}".format(trade.size))
            print("trade_close_{}".format(trade.price))
            dt = self.data.datetime.date()
            
# history
# dtopen
# dtclose
            
            
            print('---------------------------- TRADE ---------------------------------')
            print("1: Data Name:                            {}".format(trade.data._name))
            print("2: Bar Num:                              {}".format(len(trade.data)))
            print("3: Current date:                         {}".format(dt))
            print('4: Status:                               Trade Complete')
            print('5: Ref:                                  {}'.format(trade.ref))
            print('6: PnL:                                  {}'.format(round(trade.pnl,2)))
            print('7: dtopen:                               {}'.format( datetime.fromordinal(round(trade.dtopen)-1 )))
            print('8: dtclose:                               {}'.format( datetime.fromordinal(round(trade.dtclose)-1 )))
            print('9: datediff                                {}'.format(round(trade.dtclose)- round(trade.dtopen)   ))
            print('--------------------------------------------------------------------')

            
            date_open_list.append(datetime.fromordinal(round(trade.dtopen)-1 ))
            date_close_list.append(datetime.fromordinal(round(trade.dtclose)-1 ))
            Pnl_list.append(round(trade.pnl,2))
            
            
            
#Variable for our starting cash
startcash = 10000

# Create an instance of cerebro
cerebro = bt.Cerebro()

# Add our strategy
cerebro.addstrategy(BOLLStrat)
# cerebro.optstrategy(BOLLStrat, period=[5,10,14,21,100] , devfactor = [0.5,1,1.5,2])
# cerebro.optstrategy(BOLLStrat, period=[10] , devfactor = [1])



data = bt.feeds.YahooFinanceData(
    dataname='^NSEI',
    fromdate = datetime(2015,1,1),
    todate = datetime(2019,12,31),
    buffered= True,
    )

# Add the data to Cerebro
cerebro.adddata(data)

# Add a sizer
cerebro.addsizer(bt.sizers.FixedReverser, stake=10)

# Run over everything
cerebro.run()

#Get final portfolio Value
portvalue = cerebro.broker.getvalue()
pnl = portvalue - startcash

#Print out the final result 
print('Final Portfolio Value: ${}'.format(round(portvalue,2)))
print('P/L: ${}'.format(round(pnl,2)))

# Finally plot the end results
cerebro.plot(style='candlestick')
# Out:
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_-1
# trade_open_8513.8
# size_0
# trade_close_8513.8
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              21
# 3: Current date:                         2015-02-02
# 4: Status:                               Trade Complete
# 5: Ref:                                  1
# 6: PnL:                                  -253.47
# 7: dtopen:                               2015-01-16 00:00:00
# 8: dtclose:                               2015-02-02 00:00:00
# 9: datediff                                17
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_1
# trade_open_8711.7
# size_0
# trade_close_8711.7
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              29
# 3: Current date:                         2015-02-12
# 4: Status:                               Trade Complete
# 5: Ref:                                  2
# 6: PnL:                                  1.39
# 7: dtopen:                               2015-02-05 00:00:00
# 8: dtclose:                               2015-02-12 00:00:00
# 9: datediff                                7
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_-1
# trade_open_8809.35
# size_0
# trade_close_8809.35
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              36
# 3: Current date:                         2015-02-24
# 4: Status:                               Trade Complete
# 5: Ref:                                  3
# 6: PnL:                                  69.49
# 7: dtopen:                               2015-02-16 00:00:00
# 8: dtclose:                               2015-02-24 00:00:00
# 9: datediff                                8
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_1
# trade_open_8844.6
# size_0
# trade_close_8844.6
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              40
# 3: Current date:                         2015-03-02
# 4: Status:                               Trade Complete
# 5: Ref:                                  4
# 6: PnL:                                  109.25
# 7: dtopen:                               2015-02-27 00:00:00
# 8: dtclose:                               2015-03-02 00:00:00
# 9: datediff                                3
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_-1
# trade_open_8996.25
# size_0
# trade_close_8996.25
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              44
# 3: Current date:                         2015-03-09
# 4: Status:                               Trade Complete
# 5: Ref:                                  5
# 6: PnL:                                  150.27
# 7: dtopen:                               2015-03-03 00:00:00
# 8: dtclose:                               2015-03-09 00:00:00
# 9: datediff                                6
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_1
# trade_open_8699.95
# size_0
# trade_close_8699.95
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              48
# 3: Current date:                         2015-03-13
# 4: Status:                               Trade Complete
# 5: Ref:                                  6
# 6: PnL:                                  144.1
# 7: dtopen:                               2015-03-11 00:00:00
# 8: dtclose:                               2015-03-13 00:00:00
# 9: datediff                                2
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_1
# trade_open_8633.15
# size_0
# trade_close_8633.15
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              52
# 3: Current date:                         2015-03-19
# 4: Status:                               Trade Complete
# 5: Ref:                                  7
# 6: PnL:                                  116.38
# 7: dtopen:                               2015-03-16 00:00:00
# 8: dtclose:                               2015-03-19 00:00:00
# 9: datediff                                3
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_1
# trade_open_8570.9
# size_0
# trade_close_8570.9
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              60
# 3: Current date:                         2015-03-31
# 4: Status:                               Trade Complete
# 5: Ref:                                  8
# 6: PnL:                                  -29.38
# 7: dtopen:                               2015-03-20 00:00:00
# 8: dtclose:                               2015-03-31 00:00:00
# 9: datediff                                11
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_-1
# trade_open_8660.3
# size_0
# trade_close_8660.3
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              69
# 3: Current date:                         2015-04-17
# 4: Status:                               Trade Complete
# 5: Ref:                                  9
# 6: PnL:                                  -10.05
# 7: dtopen:                               2015-04-07 00:00:00
# 8: dtclose:                               2015-04-17 00:00:00
# 9: datediff                                10
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_1
# trade_open_8377.75
# size_0
# trade_close_8377.75
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              80
# 3: Current date:                         2015-05-05
# 4: Status:                               Trade Complete
# 5: Ref:                                  10
# 6: PnL:                                  -39.35
# 7: dtopen:                               2015-04-21 00:00:00
# 8: dtclose:                               2015-05-05 00:00:00
# 9: datediff                                14
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_1
# trade_open_8057.3
# size_0
# trade_close_8057.3
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              84
# 3: Current date:                         2015-05-11
# 4: Status:                               Trade Complete
# 5: Ref:                                  11
# 6: PnL:                                  185.9
# 7: dtopen:                               2015-05-07 00:00:00
# 8: dtclose:                               2015-05-11 00:00:00
# 9: datediff                                4
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_-1
# trade_open_8126.95
# size_0
# trade_close_8126.95
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              86
# 3: Current date:                         2015-05-13
# 4: Status:                               Trade Complete
# 5: Ref:                                  12
# 6: PnL:                                  -54.6
# 7: dtopen:                               2015-05-12 00:00:00
# 8: dtclose:                               2015-05-13 00:00:00
# 9: datediff                                1
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_-1
# trade_open_8365.65
# size_0
# trade_close_8365.65
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              95
# 3: Current date:                         2015-05-26
# 4: Status:                               Trade Complete
# 5: Ref:                                  13
# 6: PnL:                                  39.48
# 7: dtopen:                               2015-05-19 00:00:00
# 8: dtclose:                               2015-05-26 00:00:00
# 9: datediff                                7
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_-1
# trade_open_8433.4
# size_0
# trade_close_8433.4
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              100
# 3: Current date:                         2015-06-02
# 4: Status:                               Trade Complete
# 5: Ref:                                  14
# 6: PnL:                                  43.49
# 7: dtopen:                               2015-06-01 00:00:00
# 8: dtclose:                               2015-06-02 00:00:00
# 9: datediff                                1
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_1
# trade_open_8135.1
# size_0
# trade_close_8135.1
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              111
# 3: Current date:                         2015-06-17
# 4: Status:                               Trade Complete
# 5: Ref:                                  15
# 6: PnL:                                  -50.9
# 7: dtopen:                               2015-06-03 00:00:00
# 8: dtclose:                               2015-06-17 00:00:00
# 9: datediff                                14
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_-1
# trade_open_8224.95
# size_0
# trade_close_8224.95
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              119
# 3: Current date:                         2015-06-29
# 4: Status:                               Trade Complete
# 5: Ref:                                  16
# 6: PnL:                                  -17.74
# 7: dtopen:                               2015-06-19 00:00:00
# 8: dtclose:                               2015-06-29 00:00:00
# 9: datediff                                10
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_-1
# trade_open_8444.9
# size_0
# trade_close_8444.9
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              124
# 3: Current date:                         2015-07-06
# 4: Status:                               Trade Complete
# 5: Ref:                                  17
# 6: PnL:                                  58.75
# 7: dtopen:                               2015-07-02 00:00:00
# 8: dtclose:                               2015-07-06 00:00:00
# 9: datediff                                4
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_-1
# trade_open_8510.8
# size_0
# trade_close_8510.8
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              126
# 3: Current date:                         2015-07-08
# 4: Status:                               Trade Complete
# 5: Ref:                                  18
# 6: PnL:                                  86.53
# 7: dtopen:                               2015-07-07 00:00:00
# 8: dtclose:                               2015-07-08 00:00:00
# 9: datediff                                1
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_1
# trade_open_8360.55
# size_0
# trade_close_8360.55
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              129
# 3: Current date:                         2015-07-13
# 4: Status:                               Trade Complete
# 5: Ref:                                  19
# 6: PnL:                                  54.93
# 7: dtopen:                               2015-07-10 00:00:00
# 8: dtclose:                               2015-07-13 00:00:00
# 9: datediff                                3
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_-1
# trade_open_8608.05
# size_0
# trade_close_8608.05
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              138
# 3: Current date:                         2015-07-24
# 4: Status:                               Trade Complete
# 5: Ref:                                  20
# 6: PnL:                                  70.83
# 7: dtopen:                               2015-07-16 00:00:00
# 8: dtclose:                               2015-07-24 00:00:00
# 9: datediff                                8
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_1
# trade_open_8337.0
# size_0
# trade_close_8337.0
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              143
# 3: Current date:                         2015-07-31
# 4: Status:                               Trade Complete
# 5: Ref:                                  21
# 6: PnL:                                  161.24
# 7: dtopen:                               2015-07-28 00:00:00
# 8: dtclose:                               2015-07-31 00:00:00
# 9: datediff                                3
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_-1
# trade_open_8588.65
# size_0
# trade_close_8588.65
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              150
# 3: Current date:                         2015-08-11
# 4: Status:                               Trade Complete
# 5: Ref:                                  22
# 6: PnL:                                  91.31
# 7: dtopen:                               2015-08-06 00:00:00
# 8: dtclose:                               2015-08-11 00:00:00
# 9: datediff                                5
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_1
# trade_open_8355.85
# size_0
# trade_close_8355.85
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              153
# 3: Current date:                         2015-08-14
# 4: Status:                               Trade Complete
# 5: Ref:                                  23
# 6: PnL:                                  144.88
# 7: dtopen:                               2015-08-13 00:00:00
# 8: dtclose:                               2015-08-14 00:00:00
# 9: datediff                                1
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_1
# trade_open_8299.95
# size_0
# trade_close_8299.95
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              171
# 3: Current date:                         2015-09-09
# 4: Status:                               Trade Complete
# 5: Ref:                                  24
# 6: PnL:                                  -494.1
# 7: dtopen:                               2015-08-21 00:00:00
# 8: dtclose:                               2015-09-09 00:00:00
# 9: datediff                                19
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_-1
# trade_open_7829.1
# size_0
# trade_close_7829.1
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              179
# 3: Current date:                         2015-09-22
# 4: Status:                               Trade Complete
# 5: Ref:                                  25
# 6: PnL:                                  8.85
# 7: dtopen:                               2015-09-15 00:00:00
# 8: dtclose:                               2015-09-22 00:00:00
# 9: datediff                                7
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_1
# trade_open_7843.3
# size_0
# trade_close_7843.3
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              184
# 3: Current date:                         2015-09-30
# 4: Status:                               Trade Complete
# 5: Ref:                                  26
# 6: PnL:                                  80.95
# 7: dtopen:                               2015-09-29 00:00:00
# 8: dtclose:                               2015-09-30 00:00:00
# 9: datediff                                1
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_-1
# trade_open_7950.9
# size_0
# trade_close_7950.9
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              202
# 3: Current date:                         2015-10-28
# 4: Status:                               Trade Complete
# 5: Ref:                                  27
# 6: PnL:                                  -238.0
# 7: dtopen:                               2015-10-01 00:00:00
# 8: dtclose:                               2015-10-28 00:00:00
# 9: datediff                                27
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_1
# trade_open_8111.75
# size_0
# trade_close_8111.75
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              217
# 3: Current date:                         2015-11-20
# 4: Status:                               Trade Complete
# 5: Ref:                                  28
# 6: PnL:                                  -248.81
# 7: dtopen:                               2015-10-29 00:00:00
# 8: dtclose:                               2015-11-20 00:00:00
# 9: datediff                                22
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_-1
# trade_open_7942.7
# size_0
# trade_close_7942.7
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              225
# 3: Current date:                         2015-12-03
# 4: Status:                               Trade Complete
# 5: Ref:                                  29
# 6: PnL:                                  66.7
# 7: dtopen:                               2015-11-27 00:00:00
# 8: dtclose:                               2015-12-03 00:00:00
# 9: datediff                                6
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_1
# trade_open_7765.4
# size_0
# trade_close_7765.4
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              234
# 3: Current date:                         2015-12-16
# 4: Status:                               Trade Complete
# 5: Ref:                                  30
# 6: PnL:                                  -35.23
# 7: dtopen:                               2015-12-07 00:00:00
# 8: dtclose:                               2015-12-16 00:00:00
# 9: datediff                                9
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_-1
# trade_open_7761.95
# size_0
# trade_close_7761.95
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              245
# 3: Current date:                         2016-01-04
# 4: Status:                               Trade Complete
# 5: Ref:                                  31
# 6: PnL:                                  -103.11
# 7: dtopen:                               2015-12-18 00:00:00
# 8: dtclose:                               2016-01-04 00:00:00
# 9: datediff                                17
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_1
# trade_open_7784.65
# size_0
# trade_close_7784.65
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              260
# 3: Current date:                         2016-01-25
# 4: Status:                               Trade Complete
# 5: Ref:                                  32
# 6: PnL:                                  -315.9
# 7: dtopen:                               2016-01-05 00:00:00
# 8: dtclose:                               2016-01-25 00:00:00
# 9: datediff                                20
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_-1
# trade_open_7555.95
# size_0
# trade_close_7555.95
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              266
# 3: Current date:                         2016-02-03
# 4: Status:                               Trade Complete
# 5: Ref:                                  33
# 6: PnL:                                  163.5
# 7: dtopen:                               2016-02-01 00:00:00
# 8: dtclose:                               2016-02-03 00:00:00
# 9: datediff                                2
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_1
# trade_open_7298.2
# size_0
# trade_close_7298.2
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              277
# 3: Current date:                         2016-02-18
# 4: Status:                               Trade Complete
# 5: Ref:                                  34
# 6: PnL:                                  -91.08
# 7: dtopen:                               2016-02-09 00:00:00
# 8: dtclose:                               2016-02-18 00:00:00
# 9: datediff                                9
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_1
# trade_open_7029.75
# size_0
# trade_close_7029.75
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              285
# 3: Current date:                         2016-03-01
# 4: Status:                               Trade Complete
# 5: Ref:                                  35
# 6: PnL:                                  61.19
# 7: dtopen:                               2016-02-26 00:00:00
# 8: dtclose:                               2016-03-01 00:00:00
# 9: datediff                                4
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_-1
# trade_open_7368.85
# size_0
# trade_close_7368.85
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              295
# 3: Current date:                         2016-03-16
# 4: Status:                               Trade Complete
# 5: Ref:                                  36
# 6: PnL:                                  -87.64
# 7: dtopen:                               2016-03-02 00:00:00
# 8: dtclose:                               2016-03-16 00:00:00
# 9: datediff                                14
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_-1
# trade_open_7704.25
# size_0
# trade_close_7704.25
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              302
# 3: Current date:                         2016-03-29
# 4: Status:                               Trade Complete
# 5: Ref:                                  37
# 6: PnL:                                  116.66
# 7: dtopen:                               2016-03-21 00:00:00
# 8: dtclose:                               2016-03-29 00:00:00
# 9: datediff                                8
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_-1
# trade_open_7738.4
# size_0
# trade_close_7738.4
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              307
# 3: Current date:                         2016-04-05
# 4: Status:                               Trade Complete
# 5: Ref:                                  38
# 6: PnL:                                  48.64
# 7: dtopen:                               2016-03-31 00:00:00
# 8: dtclose:                               2016-04-05 00:00:00
# 9: datediff                                5
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_1
# trade_open_7614.35
# size_0
# trade_close_7614.35
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              311
# 3: Current date:                         2016-04-11
# 4: Status:                               Trade Complete
# 5: Ref:                                  39
# 6: PnL:                                  33.32
# 7: dtopen:                               2016-04-06 00:00:00
# 8: dtclose:                               2016-04-11 00:00:00
# 9: datediff                                5
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_-1
# trade_open_7914.7
# size_0
# trade_close_7914.7
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              321
# 3: Current date:                         2016-04-28
# 4: Status:                               Trade Complete
# 5: Ref:                                  40
# 6: PnL:                                  47.78
# 7: dtopen:                               2016-04-18 00:00:00
# 8: dtclose:                               2016-04-28 00:00:00
# 9: datediff                                10
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_1
# trade_open_7805.9
# size_0
# trade_close_7805.9
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              328
# 3: Current date:                         2016-05-09
# 4: Status:                               Trade Complete
# 5: Ref:                                  41
# 6: PnL:                                  16.41
# 7: dtopen:                               2016-05-02 00:00:00
# 8: dtclose:                               2016-05-09 00:00:00
# 9: datediff                                7
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_-1
# trade_open_7814.9
# size_0
# trade_close_7814.9
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              333
# 3: Current date:                         2016-05-16
# 4: Status:                               Trade Complete
# 5: Ref:                                  42
# 6: PnL:                                  10.26
# 7: dtopen:                               2016-05-13 00:00:00
# 8: dtclose:                               2016-05-16 00:00:00
# 9: datediff                                3
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_1
# trade_open_7749.7
# size_0
# trade_close_7749.7
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              340
# 3: Current date:                         2016-05-25
# 4: Status:                               Trade Complete
# 5: Ref:                                  43
# 6: PnL:                                  70.18
# 7: dtopen:                               2016-05-20 00:00:00
# 8: dtclose:                               2016-05-25 00:00:00
# 9: datediff                                5
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_-1
# trade_open_8069.65
# size_0
# trade_close_8069.65
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              351
# 3: Current date:                         2016-06-09
# 4: Status:                               Trade Complete
# 5: Ref:                                  44
# 6: PnL:                                  -122.86
# 7: dtopen:                               2016-05-26 00:00:00
# 8: dtclose:                               2016-06-09 00:00:00
# 9: datediff                                14
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_1
# trade_open_8110.6
# size_0
# trade_close_8110.6
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              355
# 3: Current date:                         2016-06-15
# 4: Status:                               Trade Complete
# 5: Ref:                                  45
# 6: PnL:                                  84.74
# 7: dtopen:                               2016-06-13 00:00:00
# 8: dtclose:                               2016-06-15 00:00:00
# 9: datediff                                2
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_-1
# trade_open_8088.6
# size_0
# trade_close_8088.6
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              363
# 3: Current date:                         2016-06-27
# 4: Status:                               Trade Complete
# 5: Ref:                                  46
# 6: PnL:                                  49.25
# 7: dtopen:                               2016-06-24 00:00:00
# 8: dtclose:                               2016-06-27 00:00:00
# 9: datediff                                3
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_1
# trade_open_8127.85
# size_0
# trade_close_8127.85
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              365
# 3: Current date:                         2016-06-29
# 4: Status:                               Trade Complete
# 5: Ref:                                  47
# 6: PnL:                                  48.27
# 7: dtopen:                               2016-06-28 00:00:00
# 8: dtclose:                               2016-06-29 00:00:00
# 9: datediff                                1
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_-1
# trade_open_8328.35
# size_0
# trade_close_8328.35
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              381
# 3: Current date:                         2016-07-22
# 4: Status:                               Trade Complete
# 5: Ref:                                  48
# 6: PnL:                                  -176.77
# 7: dtopen:                               2016-07-01 00:00:00
# 8: dtclose:                               2016-07-22 00:00:00
# 9: datediff                                21
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_-1
# trade_open_8590.65
# size_0
# trade_close_8590.65
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              389
# 3: Current date:                         2016-08-03
# 4: Status:                               Trade Complete
# 5: Ref:                                  49
# 6: PnL:                                  -11.7
# 7: dtopen:                               2016-07-26 00:00:00
# 8: dtclose:                               2016-08-03 00:00:00
# 9: datediff                                8
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_1
# trade_open_8551.1
# size_0
# trade_close_8551.1
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              391
# 3: Current date:                         2016-08-05
# 4: Status:                               Trade Complete
# 5: Ref:                                  50
# 6: PnL:                                  53.25
# 7: dtopen:                               2016-08-04 00:00:00
# 8: dtclose:                               2016-08-05 00:00:00
# 9: datediff                                1
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_-1
# trade_open_8711.35
# size_0
# trade_close_8711.35
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              394
# 3: Current date:                         2016-08-10
# 4: Status:                               Trade Complete
# 5: Ref:                                  51
# 6: PnL:                                  76.48
# 7: dtopen:                               2016-08-08 00:00:00
# 8: dtclose:                               2016-08-10 00:00:00
# 9: datediff                                2
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_1
# trade_open_8592.15
# size_0
# trade_close_8592.15
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              396
# 3: Current date:                         2016-08-16
# 4: Status:                               Trade Complete
# 5: Ref:                                  52
# 6: PnL:                                  78.1
# 7: dtopen:                               2016-08-11 00:00:00
# 8: dtclose:                               2016-08-16 00:00:00
# 9: datediff                                5
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_1
# trade_open_8572.55
# size_0
# trade_close_8572.55
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              406
# 3: Current date:                         2016-08-30
# 4: Status:                               Trade Complete
# 5: Ref:                                  53
# 6: PnL:                                  74.2
# 7: dtopen:                               2016-08-26 00:00:00
# 8: dtclose:                               2016-08-30 00:00:00
# 9: datediff                                4
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_-1
# trade_open_8786.2
# size_0
# trade_close_8786.2
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              414
# 3: Current date:                         2016-09-12
# 4: Status:                               Trade Complete
# 5: Ref:                                  54
# 6: PnL:                                  53.25
# 7: dtopen:                               2016-08-31 00:00:00
# 8: dtclose:                               2016-09-12 00:00:00
# 9: datediff                                12
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_1
# trade_open_8742.55
# size_0
# trade_close_8742.55
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              417
# 3: Current date:                         2016-09-16
# 4: Status:                               Trade Complete
# 5: Ref:                                  55
# 6: PnL:                                  80.99
# 7: dtopen:                               2016-09-15 00:00:00
# 8: dtclose:                               2016-09-16 00:00:00
# 9: datediff                                1
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_1
# trade_open_8706.4
# size_0
# trade_close_8706.4
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              426
# 3: Current date:                         2016-09-29
# 4: Status:                               Trade Complete
# 5: Ref:                                  56
# 6: PnL:                                  86.3
# 7: dtopen:                               2016-09-27 00:00:00
# 8: dtclose:                               2016-09-29 00:00:00
# 9: datediff                                2
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_1
# trade_open_8611.15
# size_0
# trade_close_8611.15
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              428
# 3: Current date:                         2016-10-03
# 4: Status:                               Trade Complete
# 5: Ref:                                  57
# 6: PnL:                                  132.59
# 7: dtopen:                               2016-09-30 00:00:00
# 8: dtclose:                               2016-10-03 00:00:00
# 9: datediff                                3
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_1
# trade_open_8583.4
# size_0
# trade_close_8583.4
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              437
# 3: Current date:                         2016-10-18
# 4: Status:                               Trade Complete
# 5: Ref:                                  58
# 6: PnL:                                  82.15
# 7: dtopen:                               2016-10-14 00:00:00
# 8: dtclose:                               2016-10-18 00:00:00
# 9: datediff                                4
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_1
# trade_open_8514.0
# size_0
# trade_close_8514.0
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              453
# 3: Current date:                         2016-11-10
# 4: Status:                               Trade Complete
# 5: Ref:                                  59
# 6: PnL:                                  41.6
# 7: dtopen:                               2016-11-02 00:00:00
# 8: dtclose:                               2016-11-10 00:00:00
# 9: datediff                                8
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_1
# trade_open_8108.45
# size_0
# trade_close_8108.45
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              463
# 3: Current date:                         2016-11-25
# 4: Status:                               Trade Complete
# 5: Ref:                                  60
# 6: PnL:                                  4.19
# 7: dtopen:                               2016-11-15 00:00:00
# 8: dtclose:                               2016-11-25 00:00:00
# 9: datediff                                10
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_-1
# trade_open_8142.15
# size_0
# trade_close_8142.15
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              468
# 3: Current date:                         2016-12-02
# 4: Status:                               Trade Complete
# 5: Ref:                                  61
# 6: PnL:                                  61.64
# 7: dtopen:                               2016-11-29 00:00:00
# 8: dtclose:                               2016-12-02 00:00:00
# 9: datediff                                3
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_-1
# trade_open_8261.75
# size_0
# trade_close_8261.75
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              474
# 3: Current date:                         2016-12-12
# 4: Status:                               Trade Complete
# 5: Ref:                                  62
# 6: PnL:                                  96.17
# 7: dtopen:                               2016-12-09 00:00:00
# 8: dtclose:                               2016-12-12 00:00:00
# 9: datediff                                3
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_1
# trade_open_8082.4
# size_0
# trade_close_8082.4
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              486
# 3: Current date:                         2016-12-28
# 4: Status:                               Trade Complete
# 5: Ref:                                  63
# 6: PnL:                                  -19.45
# 7: dtopen:                               2016-12-20 00:00:00
# 8: dtclose:                               2016-12-28 00:00:00
# 9: datediff                                8
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_-1
# trade_open_8179.5
# size_0
# trade_close_8179.5
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              503
# 3: Current date:                         2017-01-20
# 4: Status:                               Trade Complete
# 5: Ref:                                  64
# 6: PnL:                                  -182.45
# 7: dtopen:                               2017-01-02 00:00:00
# 8: dtclose:                               2017-01-20 00:00:00
# 9: datediff                                18
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_-1
# trade_open_8602.75
# size_0
# trade_close_8602.75
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              520
# 3: Current date:                         2017-02-15
# 4: Status:                               Trade Complete
# 5: Ref:                                  65
# 6: PnL:                                  -167.18
# 7: dtopen:                               2017-01-25 00:00:00
# 8: dtclose:                               2017-02-15 00:00:00
# 9: datediff                                21
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_1
# trade_open_8778.0
# size_0
# trade_close_8778.0
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              522
# 3: Current date:                         2017-02-17
# 4: Status:                               Trade Complete
# 5: Ref:                                  66
# 6: PnL:                                  105.7
# 7: dtopen:                               2017-02-16 00:00:00
# 8: dtclose:                               2017-02-17 00:00:00
# 9: datediff                                1
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_-1
# trade_open_8879.2
# size_0
# trade_close_8879.2
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              531
# 3: Current date:                         2017-03-03
# 4: Status:                               Trade Complete
# 5: Ref:                                  67
# 6: PnL:                                  -4.3
# 7: dtopen:                               2017-02-20 00:00:00
# 8: dtclose:                               2017-03-03 00:00:00
# 9: datediff                                11
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_-1
# trade_open_8946.9
# size_0
# trade_close_8946.9
# ...
# 7: dtopen:                               2018-12-18 00:00:00
# 8: dtclose:                               2018-12-21 00:00:00
# 9: datediff                                3
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_-1
# trade_open_10821.6
# size_0
# trade_close_10821.6
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              989
# 3: Current date:                         2019-01-11
# 4: Status:                               Trade Complete
# 5: Ref:                                  108
# 6: PnL:                                  27.09
# 7: dtopen:                               2019-01-10 00:00:00
# 8: dtclose:                               2019-01-11 00:00:00
# 9: datediff                                1
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_-1
# trade_open_10890.3
# size_0
# trade_close_10890.3
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              997
# 3: Current date:                         2019-01-23
# 4: Status:                               Trade Complete
# 5: Ref:                                  109
# 6: PnL:                                  21.99
# 7: dtopen:                               2019-01-16 00:00:00
# 8: dtclose:                               2019-01-23 00:00:00
# 9: datediff                                7
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_-1
# trade_open_10934.35
# size_0
# trade_close_10934.35
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              1010
# 3: Current date:                         2019-02-11
# 4: Status:                               Trade Complete
# 5: Ref:                                  110
# 6: PnL:                                  73.13
# 7: dtopen:                               2019-02-05 00:00:00
# 8: dtclose:                               2019-02-11 00:00:00
# 9: datediff                                6
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_-1
# trade_open_10835.3
# size_0
# trade_close_10835.3
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              1021
# 3: Current date:                         2019-02-27
# 4: Status:                               Trade Complete
# 5: Ref:                                  111
# 6: PnL:                                  77.35
# 7: dtopen:                               2019-02-26 00:00:00
# 8: dtclose:                               2019-02-27 00:00:00
# 9: datediff                                1
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_-1
# trade_open_10987.45
# size_0
# trade_close_10987.45
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              1037
# 3: Current date:                         2019-03-25
# 4: Status:                               Trade Complete
# 5: Ref:                                  112
# 6: PnL:                                  -371.45
# 7: dtopen:                               2019-03-05 00:00:00
# 8: dtclose:                               2019-03-25 00:00:00
# 9: datediff                                20
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_-1
# trade_open_11669.15
# size_0
# trade_close_11669.15
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              1046
# 3: Current date:                         2019-04-08
# 4: Status:                               Trade Complete
# 5: Ref:                                  113
# 6: PnL:                                  109.18
# 7: dtopen:                               2019-04-01 00:00:00
# 8: dtclose:                               2019-04-08 00:00:00
# 9: datediff                                7
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_-1
# trade_open_11787.15
# size_0
# trade_close_11787.15
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              1054
# 3: Current date:                         2019-04-22
# 4: Status:                               Trade Complete
# 5: Ref:                                  114
# 6: PnL:                                  127.64
# 7: dtopen:                               2019-04-16 00:00:00
# 8: dtclose:                               2019-04-22 00:00:00
# 9: datediff                                6
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_-1
# trade_open_11748.15
# size_0
# trade_close_11748.15
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              1061
# 3: Current date:                         2019-05-03
# 4: Status:                               Trade Complete
# 5: Ref:                                  115
# 6: PnL:                                  48.53
# 7: dtopen:                               2019-04-30 00:00:00
# 8: dtclose:                               2019-05-03 00:00:00
# 9: datediff                                3
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_-1
# trade_open_11709.1
# size_0
# trade_close_11709.1
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              1084
# 3: Current date:                         2019-06-06
# 4: Status:                               Trade Complete
# 5: Ref:                                  116
# 6: PnL:                                  -184.16
# 7: dtopen:                               2019-05-21 00:00:00
# 8: dtclose:                               2019-06-06 00:00:00
# 9: datediff                                16
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_-1
# trade_open_11788.85
# size_0
# trade_close_11788.85
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              1105
# 3: Current date:                         2019-07-05
# 4: Status:                               Trade Complete
# 5: Ref:                                  117
# 6: PnL:                                  -44.91
# 7: dtopen:                               2019-06-28 00:00:00
# 8: dtclose:                               2019-07-05 00:00:00
# 9: datediff                                7
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_-1
# trade_open_11046.1
# size_0
# trade_close_11046.1
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              1142
# 3: Current date:                         2019-08-29
# 4: Status:                               Trade Complete
# 5: Ref:                                  118
# 6: PnL:                                  61.42
# 7: dtopen:                               2019-08-28 00:00:00
# 8: dtclose:                               2019-08-29 00:00:00
# 9: datediff                                1
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_-1
# trade_open_11003.5
# size_0
# trade_close_11003.5
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              1153
# 3: Current date:                         2019-09-17
# 4: Status:                               Trade Complete
# 5: Ref:                                  119
# 6: PnL:                                  47.41
# 7: dtopen:                               2019-09-16 00:00:00
# 8: dtclose:                               2019-09-17 00:00:00
# 9: datediff                                1
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_-1
# trade_open_11600.2
# size_0
# trade_close_11600.2
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              1163
# 3: Current date:                         2019-10-01
# 4: Status:                               Trade Complete
# 5: Ref:                                  120
# 6: PnL:                                  317.81
# 7: dtopen:                               2019-09-23 00:00:00
# 8: dtclose:                               2019-10-01 00:00:00
# 9: datediff                                8
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_-1
# trade_open_11464.0
# size_0
# trade_close_11464.0
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              1188
# 3: Current date:                         2019-11-11
# 4: Status:                               Trade Complete
# 5: Ref:                                  121
# 6: PnL:                                  -408.76
# 7: dtopen:                               2019-10-16 00:00:00
# 8: dtclose:                               2019-11-11 00:00:00
# 9: datediff                                26
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_-1
# trade_open_11968.4
# size_0
# trade_close_11968.4
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              1196
# 3: Current date:                         2019-11-22
# 4: Status:                               Trade Complete
# 5: Ref:                                  122
# 6: PnL:                                  45.02
# 7: dtopen:                               2019-11-21 00:00:00
# 8: dtclose:                               2019-11-22 00:00:00
# 9: datediff                                1
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_-1
# trade_open_12037.7
# size_0
# trade_close_12037.7
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              1203
# 3: Current date:                         2019-12-03
# 4: Status:                               Trade Complete
# 5: Ref:                                  123
# 6: PnL:                                  8.75
# 7: dtopen:                               2019-11-26 00:00:00
# 8: dtclose:                               2019-12-03 00:00:00
# 9: datediff                                7
# --------------------------------------------------------------------
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# <backtrader.linebuffer.LineBuffer object at 0x00000253C920BEB0>
# size_-1
# trade_open_12053.95
# size_0
# trade_close_12053.95
# ---------------------------- TRADE ---------------------------------
# 1: Data Name:                            ^NSEI
# 2: Bar Num:                              1219
# 3: Current date:                         2019-12-26
# 4: Status:                               Trade Complete
# 5: Ref:                                  124
# 6: PnL:                                  -87.85
# 7: dtopen:                               2019-12-16 00:00:00
# 8: dtclose:                               2019-12-26 00:00:00
# 9: datediff                                10
# --------------------------------------------------------------------
# Final Portfolio Value: $10196.1
# P/L: $196.1
# <img src="data:image/png;base64,..." width="985.5555816638624">
# [[<Figure size 640x480 with 4 Axes>]]

# %%
pnl_dict = {"date_open":date_open_list,
            "date_close":date_close_list,
            "Pnl":Pnl_list,
            "execution_type":execution_list} 

pnl_df= pd.DataFrame(pnl_dict)

# %%
pnl_df.to_csv(r'C:\Users\wann\export_dataframe.csv')

# %%
pnl_df
# Out:
#      date_open date_close     Pnl  execution_type
# 0   2015-01-16 2015-02-02 -253.47              -1
# 1   2015-02-05 2015-02-12    1.39               1
# 2   2015-02-16 2015-02-24   69.49              -1
# 3   2015-02-27 2015-03-02  109.25               1
# 4   2015-03-03 2015-03-09  150.27              -1
# ..         ...        ...     ...             ...
# 119 2019-09-23 2019-10-01  317.81              -1
# 120 2019-10-16 2019-11-11 -408.76              -1
# 121 2019-11-21 2019-11-22   45.02              -1
# 122 2019-11-26 2019-12-03    8.75              -1
# 123 2019-12-16 2019-12-26  -87.85              -1
#
# [124 rows x 4 columns]

# %% [markdown]
# # TUNING

# %%
devfactor_tune = [0.5,1,1.5,2]
period_tune = [10,21,50,100]


for i in period_tune:
    for j in devfactor_tune:
                import pandas as pd
                import backtrader as bt

                from datetime import datetime

                

                

                class BOLLStrat(bt.Strategy):

                

                    '''

                    This is a simple mean reversion bollinger band strategy.

                

                    Entry Critria:

                        - Long:

                            - Price closes below the lower band

                        - Short:

                            - Price closes above the upper band

                    Exit Critria

                        - Long/Short: Price touching the median line

                    '''

                

                    params = (

                        ("period", i),

                        ("devfactor", j),

                        ("size", 1),

                        ("debug", False)

                        )

                

                    def __init__(self):

                        self.boll = bt.indicators.BollingerBands(period=self.p.period, devfactor=self.p.devfactor)

                

                    def next(self):

                

                        orders = self.broker.get_orders_open()

                

                        # Cancel open orders so we can track the median line

                        if orders:

                            for order in orders:

                                self.broker.cancel(order)

                

                        if not self.position:

                

                            if self.data.close > self.boll.lines.top:

                

                                self.sell(exectype=bt.Order.Close, size=self.p.size)

                                #print(data.close)

                            if self.data.close < self.boll.lines.bot:

                                self.buy(exectype=bt.Order.Close, size=self.p.size)

                                #print(data.close)

                

                        else:

                

                

                            if self.position.size > 0:

                                self.sell(exectype=bt.Order.Limit, price=self.boll.lines.mid[0], size=self.p.size)

                

                            else:

                                self.buy(exectype=bt.Order.Limit, price=self.boll.lines.mid[0], size=self.p.size)

                

                        if self.p.debug:

                            print('---------------------------- NEXT ----------------------------------')

                            print("1: Data Name:                            {}".format(data._name))

                            print("2: Bar Num:                              {}".format(len(data)))

                            print("3: Current date:                         {}".format(data.datetime.datetime()))

                            print('4: Open:                                 {}'.format(data.open[0]))

                            print('5: High:                                 {}'.format(data.high[0]))

                            print('6: Low:                                  {}'.format(data.low[0]))

                            print('7: Close:                                {}'.format(data.close[0]))

                            print('8: Volume:                               {}'.format(data.volume[0]))

                            print('9: Position Size:                       {}'.format(self.position.size))

                            print('--------------------------------------------------------------------')

                

                

                            

                            

                #Variable for our starting cash

                startcash = 10000

                

                # Create an instance of cerebro

                cerebro = bt.Cerebro()

                

                # Add our strategy

                cerebro.addstrategy(BOLLStrat)

                # cerebro.optstrategy(BOLLStrat, period=[5,10,14,21,100] , devfactor = [0.5,1,1.5,2])

                # cerebro.optstrategy(BOLLStrat, period=[10] , devfactor = [1])

                

                

                

                data = bt.feeds.YahooFinanceData(

                    dataname='^NSEI',

                    fromdate = datetime(2015,1,1),

                    todate = datetime(2019,12,31),

                    buffered= True,

                    )

                

                # Add the data to Cerebro

                cerebro.adddata(data)

                

                # Add a sizer

                cerebro.addsizer(bt.sizers.FixedReverser, stake=10)

                

                # Run over everything

                cerebro.run()

                

                #Get final portfolio Value

                portvalue = cerebro.broker.getvalue()

                pnl = portvalue - startcash

                

                #Print out the final result 
                print('period_{}'.format(i))
                print('devfactor_{}'.format(j))
                print('Final Portfolio Value: ${}'.format(round(portvalue,2)))

                print('P/L: ${}'.format(round(pnl,2)))

                

                # Finally plot the end results

                # cerebro.plot(style='candlestick')
# Out:
# period_10
# devfactor_0.5
# Final Portfolio Value: $11909.44
# P/L: $1909.44
# period_10
# devfactor_1
# Final Portfolio Value: $10196.1
# P/L: $196.1
# period_10
# devfactor_1.5
# Final Portfolio Value: $12186.08
# P/L: $2186.08
# period_10
# devfactor_2
# Final Portfolio Value: $11597.64
# P/L: $1597.64
# period_21
# devfactor_0.5
# Final Portfolio Value: $9474.11
# P/L: $-525.89
# period_21
# devfactor_1
# Final Portfolio Value: $9619.64
# P/L: $-380.36
# period_21
# devfactor_1.5
# Final Portfolio Value: $10904.75
# P/L: $904.75
# period_21
# devfactor_2
# Final Portfolio Value: $11426.64
# P/L: $1426.64
# period_50
# devfactor_0.5
# Final Portfolio Value: $9165.66
# P/L: $-834.34
# period_50
# devfactor_1
# Final Portfolio Value: $10767.9
# P/L: $767.9
# period_50
# devfactor_1.5
# Final Portfolio Value: $10893.08
# P/L: $893.08
# period_50
# devfactor_2
# Final Portfolio Value: $10558.98
# P/L: $558.98
# period_100
# devfactor_0.5
# Final Portfolio Value: $9210.37
# P/L: $-789.63
# period_100
# devfactor_1
# Final Portfolio Value: $9559.13
# P/L: $-440.87
# period_100
# devfactor_1.5
# Final Portfolio Value: $9325.33
# P/L: $-674.67
# period_100
# devfactor_2
# Final Portfolio Value: $12797.71
# P/L: $2797.71
